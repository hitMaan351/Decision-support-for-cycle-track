# %% [markdown]
# # Import Librairies

# %%
import json
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Ouverture du fichier voies cyclables

# %%
# Ouvrez le fichier
with open('geojson/france.geojson', 'r') as f:
  # Lisez le contenu du fichier
  geojson = f.read()

# Chargez les données du fichier GeoJSON en tant qu'objet Python
data = json.loads(geojson)

# Vous pouvez maintenant travailler avec les données GeoJSON en utilisant l'objet Python
print(data['type'])  # Affiche "FeatureCollection"
# Out:
# FeatureCollection

# %%
# Lisez le fichier GeoJSON en utilisant geopandas
data_gpd = gpd.read_file('geojson/france.geojson')
data_gpd
# Out:
#                  id_local reseau_loc nom_loc     id_osm num_iti code_com_d  \
# 0        geovelo_34227928       None    None   34227928    None      95218
# 1        geovelo_34209505       None    None   34209505    None      59168
# 2        geovelo_34245121       None    None   34245121    None      68224
# 3        geovelo_34243700       None    None   34243700    None      45234
# 4        geovelo_34287052       None    None   34287052    None      85083
# ...                   ...        ...     ...        ...     ...        ...
# 291138   geovelo_33880585       None    None   33880585    None      45147
# 291139   geovelo_34028032       None    None   34028032    None      46054
# 291140   geovelo_34048798       None    None   34048798    None      06018
# 291141  geovelo_495848327       None    None  495848327    None      53130
# 291142   geovelo_34119023       None    None   34119023    None      25056
#
#                                                  ame_d          regime_d  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                                AUCUN              None
# 2                                                AUCUN           ZONE 30
# 3                                                AUCUN  EN AGGLOMERATION
# 4                                       BANDE CYCLABLE              None
# ...                                                ...               ...
# 291138                                  BANDE CYCLABLE  EN AGGLOMERATION
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291141                                           AUTRE  EN AGGLOMERATION
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_d  largeur_d   local_d    statut_d code_com_g  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE      95218
# 1       UNIDIRECTIONNEL        NaN      None  EN SERVICE      59168
# 2       UNIDIRECTIONNEL        NaN      None  EN SERVICE      68224
# 3       UNIDIRECTIONNEL        NaN      None  EN SERVICE      45234
# 4       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      85083
# ...                 ...        ...       ...         ...        ...
# 291138  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      45147
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE      46054
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE      06018
# 291141  UNIDIRECTIONNEL        NaN      None  EN SERVICE      53130
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE      25056
#
#                                                  ame_g          regime_g  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                 DOUBLE SENS CYCLABLE              None
# 2                                 DOUBLE SENS CYCLABLE           ZONE 30
# 3                                 DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 4                                                AUCUN              None
# ...                                                ...               ...
# 291138                                           AUCUN              None
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291141                                           AUCUN  EN AGGLOMERATION
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_g  largeur_g   local_g    statut_g access_ame  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 1       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 2       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 3       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 4                  None        NaN      None  EN SERVICE       None
# ...                 ...        ...       ...         ...        ...
# 291138             None        NaN      None  EN SERVICE       None
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE        VTC
# 291141  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
#
#           date_maj  trafic_vit lumiere d_service  comm  \
# 0       2021-03-20         5.0    None  inconnue  None
# 1       2018-12-18         NaN    None  inconnue  None
# 2       2019-06-11        30.0    None  inconnue  None
# 3       2019-10-05        30.0    None  inconnue  None
# 4       2017-11-27         NaN    None  inconnue  None
# ...            ...         ...     ...       ...   ...
# 291138  2020-12-07        30.0    None  inconnue  None
# 291139  2018-07-12         5.0    None  inconnue  None
# 291140  2019-10-21         5.0    None  inconnue  None
# 291141  2020-11-24        50.0    True  inconnue  None
# 291142  2019-12-28         5.0    None  inconnue  None
#
#                                  source project_c        ref_geo  \
# 0       Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 1       Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 2       Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 3       Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 4       Les contributeurs OpenStreetmap      4326  OpenStreetmap
# ...                                 ...       ...            ...
# 291138  Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 291139  Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 291140  Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 291141  Les contributeurs OpenStreetmap      4326  OpenStreetmap
# 291142  Les contributeurs OpenStreetmap      4326  OpenStreetmap
#
#                                                  geometry
# 0       MULTILINESTRING ((2.09385 49.02191, 2.09422 49...
# 1       MULTILINESTRING ((3.21232 50.56662, 3.21231 50...
# 2       MULTILINESTRING ((7.33659 47.73822, 7.33732 47...
# 3       MULTILINESTRING ((1.91362 47.89896, 1.91368 47...
# 4       MULTILINESTRING ((-2.25091 46.99095, -2.25099 ...
# ...                                                   ...
# 291138  MULTILINESTRING ((1.91873 47.92172, 1.91876 47...
# 291139  MULTILINESTRING ((1.65876 44.63438, 1.65993 44...
# 291140  MULTILINESTRING ((7.05910 43.61944, 7.05903 43...
# 291141  MULTILINESTRING ((-0.76891 48.06690, -0.76939 ...
# 291142  MULTILINESTRING ((6.03053 47.22983, 6.03047 47...
#
# [291143 rows x 29 columns]

# %%
data
# Out:
# {'type': 'FeatureCollection',
#  'name': 'france',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34227928',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34227928,
#     'num_iti': None,
#     'code_com_d': '95218',
#     'ame_d': 'AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '95218',
#     'ame_g': 'AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2021-03-20',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[2.093850800000012, 49.021905699999984],
#       [2.0942173, 49.0215808]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34209505',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34209505,
#     'num_iti': None,
#     'code_com_d': '59168',
#     'ame_d': 'AUCUN',
#     'regime_d': None,
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '59168',
#     'ame_g': 'DOUBLE SENS CYCLABLE',
#     'regime_g': None,
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': 'CHAUSSEE',
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2018-12-18',
#     'trafic_vit': None,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[3.2123234, 50.5666197],
#       [3.212309600000011, 50.56656489999998],
#       [3.2121433, 50.5657722],
#       [3.212113, 50.56571]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34245121',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34245121,
#     'num_iti': None,
#     'code_com_d': '68224',
#     'ame_d': 'AUCUN',
#     'regime_d': 'ZONE 30',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '68224',
#     'ame_g': 'DOUBLE SENS CYCLABLE',
#     'regime_g': 'ZONE 30',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': 'CHAUSSEE',
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2019-06-11',
#     'trafic_vit': 30,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[7.3365904, 47.738221399999986],
#       [7.3373161, 47.7374574]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34243700',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34243700,
#     'num_iti': None,
#     'code_com_d': '45234',
#     'ame_d': 'AUCUN',
#     'regime_d': 'EN AGGLOMERATION',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '45234',
#     'ame_g': 'DOUBLE SENS CYCLABLE',
#     'regime_g': 'EN AGGLOMERATION',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': 'CHAUSSEE',
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2019-10-05',
#     'trafic_vit': 30,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[1.9136234, 47.8989623],
#       [1.913676100000012, 47.8989587],
#       [1.9144974, 47.89890339999999],
#       [1.915176199999987, 47.899235199999985]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34287052',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34287052,
#     'num_iti': None,
#     'code_com_d': '85083',
#     'ame_d': 'BANDE CYCLABLE',
#     'regime_d': None,
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': 'CHAUSSEE',
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '85083',
#     'ame_g': 'AUCUN',
#     'regime_g': None,
#     'sens_g': None,
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2017-11-27',
#     'trafic_vit': None,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[-2.2509126, 46.990946],
#       [-2.2509903, 46.9908942],
#       [-2.2511834, 46.99071029999999]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34297831',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34297831,
#     'num_iti': None,
#     'code_com_d': '59350',
#     'ame_d': 'COULOIR BUS+VELO',
#     'regime_d': None,
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': 'CHAUSSEE',
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '59350',
#     'ame_g': 'AUCUN',
#     'regime_g': None,
#     'sens_g': None,
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2020-07-22',
#     'trafic_vit': None,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[3.0740299, 50.61658379999999],
#       [3.0740651, 50.61647280000001],
#       [3.0741825, 50.6160859],
#       [3.074222200000011, 50.6159405]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34375948',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34375948,
#     'num_iti': None,
#     'code_com_d': '31188',
#     'ame_d': 'PISTE CYCLABLE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '31188',
#     'ame_g': 'PISTE CYCLABLE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2009-05-12',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[1.2123931, 43.5456578], [1.2127323, 43.5458045]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_264903558',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 264903558,
#     'num_iti': None,
#     'code_com_d': '14118',
#     'ame_d': 'COULOIR BUS+VELO',
#     'regime_d': None,
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': 'CHAUSSEE',
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '14118',
#     'ame_g': 'AUCUN',
#     'regime_g': None,
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2020-11-10',
#     'trafic_vit': None,
#     'lumiere': True,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[-0.3626413, 49.1888499], [-0.3628753, 49.188862]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_34621178',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 34621178,
#     'num_iti': None,
#     'code_com_d': '25047',
#     'ame_d': 'VOIE VERTE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '25047',
#     'ame_g': 'VOIE VERTE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2020-07-17',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[6

#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 200308728,
#     'num_iti': None,
#     'code_com_d': '29171',
#     'ame_d': 'BANDE CYCLABLE',
#     'regime_d': 'EN AGGLOMERATION',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': 'CHAUSSEE',
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '29171',
#     'ame_g': 'BANDE CYCLABLE',
#     'regime_g': 'EN AGGLOMERATION',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': 'CHAUSSEE',
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2021-02-13',
#     'trafic_vit': 50,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[-4.276530899999988, 47.845038399999986],
#       [-4.2769238, 47.8448935],
#       [-4.2771256, 47.8447996],
#       [-4.2771777, 47.84477529999999],
#       [-4.2773315, 47.8447],
#       [-4.2779332, 47.84441159999999],
#       [-4.2788127, 47.8439675],
#       [-4.2789029, 47.843922]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_92723120',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 92723120,
#     'num_iti': None,
#     'code_com_d': '35334',
#     'ame_d': 'AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '35334',
#     'ame_g': 'AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2018-06-06',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[-1.5719147, 48.1570327],
#       [-1.5723731, 48.1565177],
#       [-1.5727337, 48.15614069999999],
#       [-1.57300940000001, 48.15583329999998]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_92782305',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 92782305,
#     'num_iti': None,
#     'code_com_d': '86100',
#     'ame_d': 'VOIE VERTE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '86100',
#     'ame_g': 'VOIE VERTE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2010-12-31',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[0.2804576, 46.544007],
#       [0.280571599999988, 46.5439252],
#       [0.2806234, 46.54381],
#       [0.280628, 46.5437185],
#       [0.2806177, 46.5436896],
#       [0.28059, 46.54361179999999],
#       [0.2804512, 46.5434251],
#       [0.2803161, 46.543265],
#       [0.280165, 46.5431415]]]}},
#   {'type': 'Feature',
#    'properties': {'id_local': 'geovelo_92782283',
#     'reseau_loc': None,
#     'nom_loc': None,
#     'id_osm': 92782283,
#     'num_iti': None,
#     'code_com_d': '86100',
#     'ame_d': 'VOIE VERTE',
#     'regime_d': 'AUTRE',
#     'sens_d': 'UNIDIRECTIONNEL',
#     'largeur_d': None,
#     'local_d': None,
#     'statut_d': 'EN SERVICE',
#     'code_com_g': '86100',
#     'ame_g': 'VOIE VERTE',
#     'regime_g': 'AUTRE',
#     'sens_g': 'UNIDIRECTIONNEL',
#     'largeur_g': None,
#     'local_g': None,
#     'statut_g': 'EN SERVICE',
#     'access_ame': None,
#     'date_maj': '2010-12-31',
#     'trafic_vit': 5,
#     'lumiere': None,
#     'd_service': 'inconnue',
#     'comm': None,
#     'source': 'Les contributeurs OpenStreetmap',
#     'project_c': '4326',
#     'ref_geo': 'OpenStreetmap'},
#    'geometry': {'type': 'MultiLineString',
#     'coordinates': [[[0.27962, 46.5433911],
#       [0.279662400000012, 46.543563099999986],
#       [0.2796745, 46.5437291],
#       [0.2796725, 46.543819],
#       [0.2797338, 46.54392090000001],
#       [0.279889700000012, 46.54402159999998]]]}},
#   ...]}

# %% [markdown]
# # Suppression de colonnes

# %%
df_voie = data_gpd.copy()
df_voie = df_voie.drop(columns = ['reseau_loc','num_iti','nom_loc','date_maj','comm','source','project_c','ref_geo'])
df_voie
# Out:
#                  id_local     id_osm code_com_d  \
# 0        geovelo_34227928   34227928      95218
# 1        geovelo_34209505   34209505      59168
# 2        geovelo_34245121   34245121      68224
# 3        geovelo_34243700   34243700      45234
# 4        geovelo_34287052   34287052      85083
# ...                   ...        ...        ...
# 291138   geovelo_33880585   33880585      45147
# 291139   geovelo_34028032   34028032      46054
# 291140   geovelo_34048798   34048798      06018
# 291141  geovelo_495848327  495848327      53130
# 291142   geovelo_34119023   34119023      25056
#
#                                                  ame_d          regime_d  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                                AUCUN              None
# 2                                                AUCUN           ZONE 30
# 3                                                AUCUN  EN AGGLOMERATION
# 4                                       BANDE CYCLABLE              None
# ...                                                ...               ...
# 291138                                  BANDE CYCLABLE  EN AGGLOMERATION
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291141                                           AUTRE  EN AGGLOMERATION
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_d  largeur_d   local_d    statut_d code_com_g  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE      95218
# 1       UNIDIRECTIONNEL        NaN      None  EN SERVICE      59168
# 2       UNIDIRECTIONNEL        NaN      None  EN SERVICE      68224
# 3       UNIDIRECTIONNEL        NaN      None  EN SERVICE      45234
# 4       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      85083
# ...                 ...        ...       ...         ...        ...
# 291138  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      45147
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE      46054
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE      06018
# 291141  UNIDIRECTIONNEL        NaN      None  EN SERVICE      53130
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE      25056
#
#                                                  ame_g          regime_g  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                 DOUBLE SENS CYCLABLE              None
# 2                                 DOUBLE SENS CYCLABLE           ZONE 30
# 3                                 DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 4                                                AUCUN              None
# ...                                                ...               ...
# 291138                                           AUCUN              None
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291141                                           AUCUN  EN AGGLOMERATION
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_g  largeur_g   local_g    statut_g access_ame  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 1       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 2       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 3       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 4                  None        NaN      None  EN SERVICE       None
# ...                 ...        ...       ...         ...        ...
# 291138             None        NaN      None  EN SERVICE       None
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE        VTC
# 291141  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
#
#         trafic_vit lumiere d_service  \
# 0              5.0    None  inconnue
# 1              NaN    None  inconnue
# 2             30.0    None  inconnue
# 3             30.0    None  inconnue
# 4              NaN    None  inconnue
# ...            ...     ...       ...
# 291138        30.0    None  inconnue
# 291139         5.0    None  inconnue
# 291140         5.0    None  inconnue
# 291141        50.0    True  inconnue
# 291142         5.0    None  inconnue
#
#                                                  geometry
# 0       MULTILINESTRING ((2.09385 49.02191, 2.09422 49...
# 1       MULTILINESTRING ((3.21232 50.56662, 3.21231 50...
# 2       MULTILINESTRING ((7.33659 47.73822, 7.33732 47...
# 3       MULTILINESTRING ((1.91362 47.89896, 1.91368 47...
# 4       MULTILINESTRING ((-2.25091 46.99095, -2.25099 ...
# ...                                                   ...
# 291138  MULTILINESTRING ((1.91873 47.92172, 1.91876 47...
# 291139  MULTILINESTRING ((1.65876 44.63438, 1.65993 44...
# 291140  MULTILINESTRING ((7.05910 43.61944, 7.05903 43...
# 291141  MULTILINESTRING ((-0.76891 48.06690, -0.76939 ...
# 291142  MULTILINESTRING ((6.03053 47.22983, 6.03047 47...
#
# [291143 rows x 21 columns]

# %%
data_gpd['ame_g'].value_counts()
# Out:
# AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE    73316
# AUCUN                                             58179
# PISTE CYCLABLE                                    53430
# VOIE VERTE                                        34169
# DOUBLE SENS CYCLABLE                              24101
# BANDE CYCLABLE                                    23914
# AUTRE                                             12829
# DOUBLE SENS CYCLABLE BANDE                         7165
# COULOIR BUS+VELO                                   2100
# CHAUSSEE A VOIE CENTRALE BANALISEE                  604
# GOULOTTE                                            492
# DOUBLE SENS CYCLABLE PISTE                          440
# ACCOTEMENT REVENTU HORS CVCB                        309
# VELO RUE                                             95
# Name: ame_g, dtype: int64

# %%
#on supprime les voies qui ne sont pas des pistes cycables

# Creating the condition 
condition_1 = ((df_voie['ame_g'].str.contains("AUCUN")) |
            (df_voie['ame_g'].str.contains("AUTRE")) |
            (df_voie['ame_g'].str.contains("GOULOTTE")))
condition_2 = ((df_voie['ame_d'].str.contains("AUCUN")) |
            (df_voie['ame_d'].str.contains("AUTRE")) |
            (df_voie['ame_d'].str.contains("GOULOTTE")))

# using the condition to filter the rows
df_voie = df_voie[~(condition_1&condition_2)]
df_voie
# Out:
#                 id_local    id_osm code_com_d  \
# 0       geovelo_34227928  34227928      95218
# 1       geovelo_34209505  34209505      59168
# 2       geovelo_34245121  34245121      68224
# 3       geovelo_34243700  34243700      45234
# 4       geovelo_34287052  34287052      85083
# ...                  ...       ...        ...
# 291137  geovelo_33846334  33846334      92022
# 291138  geovelo_33880585  33880585      45147
# 291139  geovelo_34028032  34028032      46054
# 291140  geovelo_34048798  34048798      06018
# 291142  geovelo_34119023  34119023      25056
#
#                                                  ame_d          regime_d  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                                AUCUN              None
# 2                                                AUCUN           ZONE 30
# 3                                                AUCUN  EN AGGLOMERATION
# 4                                       BANDE CYCLABLE              None
# ...                                                ...               ...
# 291137  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291138                                  BANDE CYCLABLE  EN AGGLOMERATION
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_d  largeur_d   local_d    statut_d code_com_g  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE      95218
# 1       UNIDIRECTIONNEL        NaN      None  EN SERVICE      59168
# 2       UNIDIRECTIONNEL        NaN      None  EN SERVICE      68224
# 3       UNIDIRECTIONNEL        NaN      None  EN SERVICE      45234
# 4       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      85083
# ...                 ...        ...       ...         ...        ...
# 291137  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92022
# 291138  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      45147
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE      46054
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE      06018
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE      25056
#
#                                                  ame_g          regime_g  \
# 0       AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1                                 DOUBLE SENS CYCLABLE              None
# 2                                 DOUBLE SENS CYCLABLE           ZONE 30
# 3                                 DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 4                                                AUCUN              None
# ...                                                ...               ...
# 291137  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291138                                           AUCUN              None
# 291139                                      VOIE VERTE             AUTRE
# 291140  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 291142                                      VOIE VERTE             AUTRE
#
#                  sens_g  largeur_g   local_g    statut_g access_ame  \
# 0       UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 1       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 2       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 3       UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None
# 4                  None        NaN      None  EN SERVICE       None
# ...                 ...        ...       ...         ...        ...
# 291137  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291138             None        NaN      None  EN SERVICE       None
# 291139  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
# 291140  UNIDIRECTIONNEL        NaN      None  EN SERVICE        VTC
# 291142  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None
#
#         trafic_vit lumiere d_service  \
# 0              5.0    None  inconnue
# 1              NaN    None  inconnue
# 2             30.0    None  inconnue
# 3             30.0    None  inconnue
# 4              NaN    None  inconnue
# ...            ...     ...       ...
# 291137         5.0    None  inconnue
# 291138        30.0    None  inconnue
# 291139         5.0    None  inconnue
# 291140         5.0    None  inconnue
# 291142         5.0    None  inconnue
#
#                                                  geometry
# 0       MULTILINESTRING ((2.09385 49.02191, 2.09422 49...
# 1       MULTILINESTRING ((3.21232 50.56662, 3.21231 50...
# 2       MULTILINESTRING ((7.33659 47.73822, 7.33732 47...
# 3       MULTILINESTRING ((1.91362 47.89896, 1.91368 47...
# 4       MULTILINESTRING ((-2.25091 46.99095, -2.25099 ...
# ...                                                   ...
# 291137  MULTILINESTRING ((2.19853 48.81649, 2.19862 48...
# 291138  MULTILINESTRING ((1.91873 47.92172, 1.91876 47...
# 291139  MULTILINESTRING ((1.65876 44.63438, 1.65993 44...
# 291140  MULTILINESTRING ((7.05910 43.61944, 7.05903 43...
# 291142  MULTILINESTRING ((6.03053 47.22983, 6.03047 47...
#
# [276375 rows x 21 columns]

# %% [markdown]
# # Ouverture du fichier accidents vélo

# %%
data_acc_velo = pd.read_csv('row_dataset_accidents_velo.csv',sep=',')
data_acc_velo
# Out:
#            Num_Acc id_vehicule num_veh  senc  catv  obs  obsm  choc  manv  \
# 0     202100000001     201 764     B01     1     1    0     2     1     1
# 1     202100000006     201 752     B01     2     1    0     0     5     1
# 2     202100000038     201 693     B01     1     1    0     2     1     1
# 3     202100000051     201 658     A01     3     1    0     2     8     1
# 4     202100000070     201 625     B01     0     1    0     2     0     0
# ...            ...         ...     ...   ...   ...  ...   ...   ...   ...
# 5613  202100056346     101 181     A01     1     1    0     1     1    13
# 5614  202100056362     101 157     B01     2     1    0     2     0     1
# 5615  202100056404     101 079     A01     1     1    0     2     1    25
# 5616  202100056424     101 041     A01     1     1    0     2     1     1
# 5617  202100056508     100 898     A01     2     1    0     0     8     1
#
#       motor  occutc  jour  mois    an   hrmn  lum dep    com  agg  int  atm  \
# 0         5     NaN    30    11  2021  07:32    2  30  30319    1    1    1
# 1         5     NaN    23    11  2021  11:10    1  68  68004    2    3    1
# 2         5     NaN     2     9  2021  11:00    1  71  71540    2    1    1
# 3         5     NaN     9    11  2021  23:30    5  31  31555    2    9    1
# 4        -1     NaN     4    11  2021  17:31    1  60  60057    2    1    1
# ...     ...     ...   ...   ...   ...    ...  ...  ..    ...  ...  ...  ...
# 5613      0     NaN     3     1  2021  18:20    5  94  94043    2    1    1
# 5614      5     NaN     4     1  2021  08:20    1  64  64138    2    3    1
# 5615      5     NaN     1     1  2021  16:55    5  54  54395    2    2    1
# 5616      5     NaN     2     1  2021  15:40    1  75  75110    2    1    8
# 5617      5     NaN     1     1  2021  12:20    1  64  64400    1    1    1
#
#       col                           adr            lat            long  catr  \
# 0       1                        CD 981  44,0389580000    4,3480220000     3
# 1       2     Rue Charles Edouard Amiot  47,6142390000    7,2343360000     4
# 2       2          Route des Perraudins  46,7668890000    4,4566240000     4
# 3       3          SQUARE DE L HERACLES  43,6074900000    1,4281200000     4
# 4       3          Rue du Pont d’Arcole  49,4262285502    2,0853413343     4
# ...   ...                           ...            ...             ...   ...
# 5613    7         FONTAINEBLEAU (AV DE)  48,8104900000    2,3619400000     3
# 5614    1               Impasse Cap-sus  43,2309460000   -0,2765840000     3
# 5615    3      MOUILLERON (RUE GABRIEL)  48,6849869839    6,1760189384     4
# 5616    3  RUE DES ECLUSES SAINT MARTIN  48,8769050000    2,3665940000     4
# 5617    7               chemin d'Arribe  43,1465730000   -0,1955440000     4
#
#                               voie  v1   v2  circ  nbv  vosp  prof   pr  pr1  \
# 0                              981  -1  NaN     2    2     0     1  (1)  (1)
# 1                              NaN  -1  NaN     2    2     0     1  (1)  (1)
# 2                              NaN  -1  NaN     2    2     0     1  (1)  (1)
# 3             SQUARE DE L HERACLES   0  NaN     2    2     0     1  (1)  (1)
# 4                              NaN  -1  NaN     2    2    -1     1  (1)  (1)
# ...                            ...  ..  ...   ...  ...   ...   ...  ...  ...
# 5613         FONTAINEBLEAU (AV DE)   0  NaN     1    1     1     1    0    0
# 5614                           937  -1  NaN     2    2     0     1   11  100
# 5615                           NaN   0  NaN     1    2     2     1  (1)  (1)
# 5616  RUE DES ECLUSES SAINT MARTIN   0  NaN     1    1     2     2  (1)  (1)
# 5617                             2  -1  NaN     2    2     0     2    0    0
#
#       plan lartpc larrout  surf  infra  situ  vma
# 0        1    NaN      -1     1      0     1   80
# 1        1    NaN       4     1      0     1   50
# 2        1    NaN      -1     1      0     1   50
# 3        1    NaN      -1     1      2     1   50
# 4        1    NaN     5,5     1      0     1   -1
# ...    ...    ...     ...   ...    ...   ...  ...
# 5613     1    NaN      -1     1      0     1   30
# 5614     1    NaN      -1     1      0     1   50
# 5615     1    NaN      -1     1     -1     1   30
# 5616     1    NaN      -1     1     -1     5   50
# 5617     2    NaN      -1     2      0     1   50
#
# [5618 rows x 42 columns]

# %%
df_accident = data_acc_velo.copy()
df_accident = df_accident.drop(columns=['id_vehicule','num_veh','occutc','com'])

# %%
df_accident = df_accident.rename(columns={"long": "longitude"})

# %%
df_accident["longitude"]=df_accident["longitude"].str.replace(',','.')
df_accident['longitude'] = df_accident['longitude'].astype(float)

df_accident["lat"]=df_accident["lat"].str.replace(',','.')
df_accident['lat'] = df_accident['lat'].astype(float)

df_accident['longitude'].head()
# Out:
# 0    4.348022
# 1    7.234336
# 2    4.456624
# 3    1.428120
# 4    2.085341
# Name: longitude, dtype: float64

# %%
from shapely.geometry import MultiLineString

# %% [markdown]
# # Transformation en Geodataframe

# %%
df_accident['geometry'] = df_accident.apply(lambda x: Point(x['longitude'], x['lat']), axis=1)
gdf_accident = gpd.GeoDataFrame(df_accident, geometry='geometry')
gdf_accident = gdf_accident[(gdf_accident['longitude']>2.26)&(gdf_accident['longitude']<2.4)]
gdf_accident = gdf_accident[(gdf_accident['lat']>48.8)&(gdf_accident['lat']<48.9)]

gdf_accident.shape
# Out:
# (1096, 39)

# %%
gdf_voie = gpd.GeoDataFrame(df_voie, geometry='geometry')
gdf_voie.head(1)
# Out:
#            id_local    id_osm code_com_d  \
# 0  geovelo_34227928  34227928      95218
#
#                                             ame_d regime_d           sens_d  \
# 0  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE    AUTRE  UNIDIRECTIONNEL
#
#    largeur_d local_d    statut_d code_com_g  \
# 0        NaN    None  EN SERVICE      95218
#
#                                             ame_g regime_g           sens_g  \
# 0  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE    AUTRE  UNIDIRECTIONNEL
#
#    largeur_g local_g    statut_g access_ame  trafic_vit lumiere d_service  \
# 0        NaN    None  EN SERVICE       None         5.0    None  inconnue
#
#                                             geometry
# 0  MULTILINESTRING ((2.09385 49.02191, 2.09422 49...

# %% [markdown]
# ### On crée des range de coordonnées pour la zone de Paris

# %%
coordonnes = [[2.26,48.8],[2.29,48.81],[2.31,48.82],[2.34,48.83],[2.365,48.85],[2.383,48.89],[2.4,48.9]]

# %% [markdown]
# ### On filtre les deux dataframe pour chaque range de longitude et latitude

# %%
gdf_accident_test = gdf_accident.copy()
liste_df = []

for i in range (len(coordonnes)-1) :
    gdf_accident_new = gdf_accident_test[(gdf_accident_test['longitude']>coordonnes[i][0])&(gdf_accident_test['longitude']<coordonnes[i+1][0])]
    gdf_accident_new = gdf_accident_new[(gdf_accident_new['lat']>coordonnes[i][1])&(gdf_accident_new['lat']<coordonnes[i+1][1])]
    liste_df.append(gdf_accident_new)
    
for i in range(len(liste_df)):
    print(liste_df[i].shape)


#gdf_accident_test.loc[0,'geometry'] = Point(2.0590, 49.0589)
#gdf_accident_test.loc[1,'geometry'] = Point(7.30, 47)
#gdf_accident_test.loc[2,'geometry'] = Point(3.21, 50)
#gdf_accident_test.loc[3,'geometry'] = Point(1.91, 47.89)
#gdf_accident_test.loc[4,'geometry'] = Point(-2.25, 46.99)
#gdf_accident_test.loc[5,'geometry'] = Point(3.07, 50.61)
# Out:
# (2, 39)
# (12, 39)
# (26, 39)
# (51, 39)
# (136, 39)
# (2, 39)

# %%
gdf_voie.geometry.set_crs('EPSG:4326', inplace=True)
for i in range(len(liste_df)):
    liste_df[i].geometry.set_crs('EPSG:4326', inplace=True)

# %%
gdf_voie_test = gdf_voie.copy()

# %%
gdf_voie_test['geometry'] = gdf_voie_test['geometry'].apply(lambda x: x.geoms[0])

# %%
def filter_dataframe(df, min_lat, max_lat, min_lon, max_lon):
    # filtrer les lignes qui ont des coordonnées géographiques dans les limites données
    filtered_df = df[(df['geometry'].apply(lambda x: x.coords[0][1]) >= min_lat) & 
                    (df['geometry'].apply(lambda x: x.coords[0][1]) <= max_lat) & 
                    (df['geometry'].apply(lambda x: x.coords[0][0]) >= min_lon) & 
                    (df['geometry'].apply(lambda x: x.coords[0][0]) <= max_lon)]
    return filtered_df

# %%
liste_df_voie = []

for i in range(len(coordonnes)-1):
    print(coordonnes[i][0],coordonnes[i+1][0],coordonnes[i][1],coordonnes[i+1][1])
    gdf_filtered =filter_dataframe(gdf_voie_test,coordonnes[i][1],coordonnes[i+1][1],coordonnes[i][0],coordonnes[i+1][0])
    liste_df_voie.append(gdf_filtered)
# Out:
# 2.26 2.29 48.8 48.81
# 2.29 2.31 48.81 48.82
# 2.31 2.34 48.82 48.83
# 2.34 2.365 48.83 48.85
# 2.365 2.383 48.85 48.89
# 2.383 2.4 48.89 48.9

# %%
for i in range(len(liste_df_voie)):
    print(liste_df_voie[i].shape)
# Out:
# (98, 21)
# (161, 21)
# (284, 21)
# (434, 21)
# (736, 21)
# (139, 21)

# %%
for i in range(len(liste_df_voie)):
    liste_df_voie[i] = liste_df_voie[i].to_crs(epsg=2154)
    lie_df[i] = liste_df[i].to_crs(epsg=2154)

# %% [markdown]
# # Calcul des distances pour chaque point et linestring

# %%
for j in range(len(liste_df_voie)):
    print(j)
    for i, point in liste_df[j].iterrows():
        liste_df[j].at[i,"distance"] = liste_df_voie[j].distance(point.geometry).min()

# %%
for i, point in liste_df[0].iterrows():
    liste_df[0].at[i,"distance"] = liste_df_voie[0].distance(point.geometry).min()
    liste_df[0].at[i,"nearest_road"] = liste_df_voie[0].distance(point.geometry).idxmin()

liste_df[0]["nearest_road"] = liste_df[0]["nearest_road"].astype('int')
liste_df[0]
# Out:
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 2885  202100031333     2     1    1     0     2     1      5     2     7
# 3814  202100039165     1     1    0     2     8     1      6    19     5
#
#         an   hrmn  lum dep  agg  int  atm  col                           adr  \
# 2885  2021  18:40    1  92    2    1    1    3           LAZARE CARNOT (RUE)
# 3814  2021  15:06    1  92    2    1    2    3  VANVES BOULEVARD DE N° PAIRS
#
#            lat  longitude  catr voie  v1   v2  circ  nbv  vosp  prof pr pr1  \
# 2885  48.80949    2.27123     4  NaN   0  NaN     2    2     0     1  0   0
# 3814  48.80993    2.28259     3   72   0  NaN     2    2     0     1  0   1
#
#       plan lartpc larrout  surf  infra  situ  vma  \
# 2885     1    NaN      -1     1      0     1   30
# 3814     1    NaN      -1     2      0     1   50
#
#                             geometry    distance  nearest_road
# 2885  POINT (646479.832 6856848.981)   41.276557        286435
# 3814  POINT (647314.520 6856890.263)  148.441738        167205

# %%
liste_merged = []
liste_merged.append((liste_df[0].merge(liste_df_voie[0], left_on='nearest_road', right_index=True)))

liste_merged[0]
# Out:
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 2885  202100031333     2     1    1     0     2     1      5     2     7
# 3814  202100039165     1     1    0     2     8     1      6    19     5
#
#         an   hrmn  lum dep  agg  int  atm  col                           adr  \
# 2885  2021  18:40    1  92    2    1    1    3           LAZARE CARNOT (RUE)
# 3814  2021  15:06    1  92    2    1    2    3  VANVES BOULEVARD DE N° PAIRS
#
#            lat  longitude  catr voie  v1   v2  circ  nbv  vosp  prof pr pr1  \
# 2885  48.80949    2.27123     4  NaN   0  NaN     2    2     0     1  0   0
# 3814  48.80993    2.28259     3   72   0  NaN     2    2     0     1  0   1
#
#       plan lartpc larrout  surf  infra  situ  vma  \
# 2885     1    NaN      -1     1      0     1   30
# 3814     1    NaN      -1     2      0     1   50
#
#                           geometry_x    distance  nearest_road  \
# 2885  POINT (646479.832 6856848.981)   41.276557        286435
# 3814  POINT (647314.520 6856890.263)  148.441738        167205
#
#                id_local     id_osm code_com_d  \
# 2885   geovelo_37655991   37655991      92023
# 3814  geovelo_755707363  755707363      92020
#
#                                                ame_d          regime_d  \
# 2885                                           AUCUN  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
#
#                sens_d  largeur_d local_d    statut_d code_com_g  \
# 2885  UNIDIRECTIONNEL        NaN    None  EN SERVICE      92023
# 3814  UNIDIRECTIONNEL        NaN    None  EN SERVICE      92020
#
#                                                ame_g          regime_g  \
# 2885                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
#
#                sens_g  largeur_g   local_g    statut_g access_ame  trafic_vit  \
# 2885  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 3814  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
#
#      lumiere d_service                                         geometry_y
# 2885    None  inconnue  LINESTRING (646440.773 6856862.329, 646438.830...
# 3814    None  inconnue  LINESTRING (647271.267 6856742.089, 647274.993...

# %%
for i, point in liste_df[1].iterrows():
    liste_df[1].at[i,"distance"] = liste_df_voie[1].distance(point.geometry).min()
    liste_df[1].at[i,"nearest_road"] = liste_df_voie[1].distance(point.geometry).idxmin()

liste_df[1]["nearest_road"] = liste_df[1]["nearest_road"].astype('int')

liste_merged.append((liste_df[1].merge(liste_df_voie[1], left_on='nearest_road', right_index=True)))

liste_merged[1]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 263   202100003857     1     1    0     1     3     1      5     9    12
# 1033  202100013414     0     1    0     2     1     1      5    13    10
# 1678  202100019528     2     1    0     2     1     1      5    11     9
# 1679  202100019528     3     1    0     2     8    19      5    11     9
# 1947  202100022128     2     1    0     0     6     1      6    28     8
# 2019  202100022760     2     1    0     2     1     2      5    24     8
# 3789  202100038994     3     1    0     0     0     0      0    21     5
# 4064  202100041423     3     1    0     2     3     9      5     3     5
# 4290  202100043213     1     1    0     2     1     5      5    21     4
# 4443  202100044614     2     1    8     0     1     1      0     8     4
# 4775  202100047147     0     1    0     0     0    26      5    21     3
# 4823  202100047667     2     1    0     2     3    11      6    17     3
#
#         an   hrmn  lum dep  agg  int  atm  col                        adr  \
# 263   2021  10:11    1  92    2    1    1    6       PELLETAN RUE CAMILLE
# 1033  2021  11:20    1  92    2    3    1    3   PIERRE LAROUSSE (AVENUE)
# 1678  2021  18:43    1  92    2    1    1    3              RAYMOND DAVID
# 1679  2021  18:43    1  92    2    1    1    3              RAYMOND DAVID
# 1947  2021  10:55    1  92    2    1    1    7        ETIENNE DOLET (RUE)
# 2019  2021  18:40    1  92    2    1    1    2       CHATEAUBRIAND RUE DE
# 3789  2021  21:00    5  92    2    3    1    7    Paul vaillant couturier
# 4064  2021  13:55    1  92    2    6    1    3                  CAMELINAT
# 4290  2021  10:30    1  92    2    2    1    3  BROSSOLETTE AVENUE PIERRE
# 4443  2021  10:00    1  92    2    1    1    6  BROSSOLETTE AVENUE PIERRE
# 4775  2021  11:20    1  92    2    3    1    7  BROSSOLETTE AVENUE PIERRE
# 4823  2021  15:20    1  92    2    1    2    3               GABRIEL PERI
#
#             lat  longitude  catr                       voie  v1   v2  circ  \
# 263   48.816749   2.309465     4                        NaN   0  NaN     1
# 1033  48.819554   2.306153     3                         50   0  NaN    -1
# 1678  48.816288   2.295262     3                         63   0  NaN     2
# 1679  48.816288   2.295262     3                         63   0  NaN     2
# 1947  48.816481   2.297320     4        ETIENNE DOLET (RUE)   0  NaN     2
# 2019  48.811710   2.309230     4       CHATEAUBRIAND RUE DE   0  NaN     1
# 3789  48.817050   2.291910     4                        NaN   0  NaN     1
# 4064  48.815960   2.295330     3                  CAMELINAT   0  NaN     1
# 4290  48.817696   2.307885     3  BROSSOLETTE AVENUE PIERRE   0  NaN     2
# 4443  48.814861   2.303942     3  BROSSOLETTE AVENUE PIERRE   0  NaN     2
# 4775  48.812810   2.301550     3                        906   0  NaN     2
# 4823  48.819256   2.295791     3               GABRIEL PERI   0  NaN     2
#
#       nbv  vosp  prof pr pr1  plan lartpc larrout  surf  infra  situ  vma  \
# 263     1     0     1  0   0     1    NaN      -1     1      0     1   30
# 1033    1     0     1  0   0     1    NaN      -1     1      0     1   50
# 1678    2     0     1  0   0     1    NaN      -1     1      0     1   50
# 1679    2     0     1  0   0     1    NaN      -1     1      0     1   50
# 1947    1     0     1  0   0     1    NaN      -1     1      0     1   30
# 2019    1     0     1  0   0     1    NaN      -1     1      0     1   30
# 3789    1     1     1  0   0     1    NaN      -1     1      0     5   50
# 4064    1     0     1  0   0     2    NaN      -1     1      5     1   50
# 4290    4     1     1  0   1     1    NaN      -1     1      0     1   50
# 4443    4     2     1  0   0     1    NaN      -1     1      0     5   50
# 4775    4     1     1  0   0     1    NaN      -1     1      0     1   50
# 4823    2     0     1  0   0     1    NaN      -1     2      0     1   50
#
#                           geometry_x   distance  nearest_road  \
# 263   POINT (649294.766 6857630.845)  80.140361        166823
# 1033  POINT (649054.277 6857944.809)  56.617679        286266
# 1678  POINT (648251.446 6857588.836)   6.624460        253512
# 1679  POINT (648251.446 6857588.836)   6.624460        253512
# 1947  POINT (648402.726 6857608.864)  19.307846         69696
# 2019  POINT (649272.601 6857070.730)  27.237003         31043
# 3789  POINT (648006.048 6857675.731)   1.381879         69223
# 4064  POINT (648256.085 6857552.291)   7.624864         40447
# 4290  POINT (649179.687 6857737.116)   0.031723         43234
# 4443  POINT (648887.402 6857424.479)  96.713254         42801
# 4775  POINT (648709.709 6857197.996)   0.886207         43236
# 4823  POINT (648293.218 6857918.427)  26.568491         11199
#
#                id_local     id_osm code_com_d  \
# 263   geovelo_659513577  659513577      92049
# 1033   geovelo_25396506   25396506      92046
# 1678  geovelo_540065626  540065626      92046
# 1679  geovelo_540065626  540065626      92046
# 1947  geovelo_265280387  265280387      92046
# 2019  geovelo_526288352  526288352      92049
# 3789   geovelo_17239677   17239677      92046
# 4064  geovelo_507553980  507553980      92046
# 4290   geovelo_98895107   98895107      92046
# 4443  geovelo_429350617  429350617      92046
# 4775  geovelo_266361445  266361445      92049
# 4823   geovelo_45317749   45317749      92046
#
#                                                ame_d          regime_d  \
# 263                                            AUCUN  EN AGGLOMERATION
# 1033                                           AUCUN  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1679  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1947                                           AUCUN  EN AGGLOMERATION
# 2019                                  PISTE CYCLABLE  EN AGGLOMERATION
# 3789                                           AUCUN  EN AGGLOMERATION
# 4064                                  PISTE CYCLABLE             AUTRE
# 4290                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4443                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4775                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4823  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
#
#                sens_d  largeur_d   local_d    statut_d code_com_g  \
# 263   UNIDIRECTIONNEL        NaN      None  EN SERVICE      92049
# 1033  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 1679  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 1947  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 2019  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      92049
# 3789  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 4064  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 4290  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE      92046
# 4443  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE      92046
# 4775  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE      92049
# 4823  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
#
#                                                ame_g          regime_g  \
# 263                                   BANDE CYCLABLE  EN AGGLOMERATION
# 1033                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1679  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 1947                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 2019                                           AUCUN              None
# 3789                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 4064                                           AUCUN              None
# 4290                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4443                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4775                                  PISTE CYCLABLE  EN AGGLOMERATION
# 4823  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
#
#                sens_g  largeur_g   local_g    statut_g access_ame  trafic_vit  \
# 263   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 1033  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# 1679  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# 1947  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        20.0
# 2019             None        NaN      None  EN SERVICE       None        50.0
# 3789  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 4064             None        NaN      None  EN SERVICE       None         5.0
# 4290  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE       None        50.0
# 4443  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE       None        50.0
# 4775  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE       None        50.0
# 4823  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
#
#      lumiere d_service                                         geometry_y
# 263     True  inconnue  LINESTRING (649246.431 6857566.922, 649242.525...
# 1033    True  inconnue  LINESTRING (649024.597 6857993.023, 649030.113...
# 1678    True  inconnue  LINESTRING (648264.439 6857585.820, 648257.143...
# 1679    True  inconnue  LINESTRING (648264.439 6857585.820, 648257.143...
# 1947    None  inconnue  LINESTRING (648299.032 6857728.909, 648287.828...
# 2019    None  inconnue  LINESTRING (649256.329 6857098.693, 649249.268...
# 3789    True  inconnue  LINESTRING (648007.193 6857678.212, 648002.302...
# 4064    None  inconnue  LINESTRING (648260.509 6857558.501, 648251.748...
# 4290    None  inconnue  LINESTRING (649179.733 6857737.213, 649177.601...
# 4443    None  inconnue  LINESTRING (649002.012 6857548.889, 648970.437...
# 4775    None  inconnue  LINESTRING (648711.151 6857201.564, 648709.441...
# 4823    True  inconnue  LINESTRING (648268.570 6857928.588, 648266.817...

# %%
for i, point in liste_df[2].iterrows():
    liste_df[2].at[i,"distance"] = liste_df_voie[2].distance(point.geometry).min()
    liste_df[2].at[i,"nearest_road"] = liste_df_voie[2].distance(point.geometry).idxmin()

liste_df[2]["nearest_road"] = liste_df[2]["nearest_road"].astype('int')

liste_merged.append((liste_df[2].merge(liste_df_voie[2], left_on='nearest_road', right_index=True)))

liste_merged[2]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 159   202100002461     3     1    0     2     1     1      5    17    12
# 1181  202100014843     1     1    0     4     1    19      5     6    10
# 206   202100002967     1     1    0     1     1     1      5    14    12
# 686   202100009462     1     1    9     0     1     1      5     4    11
# 1732  202100020105     2     1    0     2     3     1      5     8     9
# 752   202100010563     2     1    0     2     8     1      5    27    10
# 876   202100011850     3     1    0     0     0     1      5    21    10
# 4773  202100047139     1     1    0     2     1     1      5    21     3
# 997   202100013111     2     1    0     2     1     1      5    15    10
# 1035  202100013419     1     1    0     2     1     1      5    13    10
# 1281  202100015950     2     1    0     0     1     1      5    30     9
# 1330  202100016352     1     1    0     2     1     9      5    28     9
# 1676  202100019512     1     1    0     2     8     9      5    10     9
# 1720  202100019903     2     1    0     2     0     1      5     9     9
# 4428  202100044483     2     1    0     2     1     1      5    10     4
# 2519  202100027762     1     1    0     0     0    21      5    12     7
# 2683  202100029440     2     1    0     1     1     1      5    11     7
# 2734  202100030015     1     1    0     2     3     1      5     7     7
# 2784  202100030412     1     1    0     2     8     1      5     6     7
# 3264  202100034614     2     1    0     2     2     1      5    12     6
# 3457  202100035949     2     1    0     2     1    17      5     7     6
# 4110  202100041928     2     1    0     1     1    25      5    30     4
# 4523  202100045244     1     1    8     2     8    21      5     3     4
# 4667  202100046377     2     1    0     2     5     1      5    26     3
# 4923  202100048568     1     1    0     0     0     1      5    10     3
# 5523  202100055070     1     1    0     2     1     1      5    14     1
# 3264  geovelo_666203873  666203873      75114             AUCUN
# 3457    geovelo_4040540    4040540      75114    BANDE CYCLABLE
# 4110   geovelo_23202856   23202856      75114             AUCUN
# 4523    geovelo_4261972    4261972      75114             AUCUN
# 4667  geovelo_827435610  827435610      75114    PISTE CYCLABLE
# 4923  geovelo_662409824  662409824      75114    BANDE CYCLABLE
# 5523    geovelo_4261999    4261999      75114             AUCUN
#
#               regime_d           sens_d  largeur_d   local_d    statut_d  \
# 159   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 1181  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 206              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 686              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 1732             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 752   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 876   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 4773  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 997            ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1035  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 1281           ZONE 30  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 1330           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1676  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1720             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 4428             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 2519             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 2683  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 2734  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2784  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 3264  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 3457  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 4110           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4523           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4667  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 4923  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 5523           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
#
#      code_com_g                 ame_g          regime_g           sens_g  \
# 159       75114                 AUCUN  EN AGGLOMERATION  UNIDIRECTIONNEL
# 1181      75114                 AUCUN  EN AGGLOMERATION  UNIDIRECTIONNEL
# 206       75114                 AUCUN              None             None
# 686       75114                 AUCUN              None             None
# 1732      75114                 AUCUN              None             None
# 752       75114                 AUCUN              None             None
# 876       75114                 AUCUN  EN AGGLOMERATION  UNIDIRECTIONNEL
# 4773      75114                 AUCUN  EN AGGLOMERATION  UNIDIRECTIONNEL
# 997       75114  DOUBLE SENS CYCLABLE           ZONE 30  UNIDIRECTIONNEL
# 1035      92049                 AUCUN              None             None
# 1281      75114      COULOIR BUS+VELO           ZONE 30  UNIDIRECTIONNEL
# 1330      75114  DOUBLE SENS CYCLABLE           ZONE 30  UNIDIRECTIONNEL
# 1676      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 1720      75114                 AUCUN              None             None
# 4428      75114                 AUCUN              None             None
# 2519      75114                 AUCUN              None             None
# 2683      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 2734      75114  DOUBLE SENS CYCLABLE  EN AGGLOMERATION  UNIDIRECTIONNEL
# 2784      75114                 AUCUN              None             None
# 3264      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 3457      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 4110      75114  DOUBLE SENS CYCLABLE           ZONE 30  UNIDIRECTIONNEL
# 4523      75114  DOUBLE SENS CYCLABLE           ZONE 30  UNIDIRECTIONNEL
# 4667      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 4923      75114      COULOIR BUS+VELO  EN AGGLOMERATION  UNIDIRECTIONNEL
# 5523      75114  DOUBLE SENS CYCLABLE           ZONE 30  UNIDIRECTIONNEL
#
#       largeur_g   local_g    statut_g access_ame  trafic_vit lumiere  \
# 159         NaN      None  EN SERVICE       None        30.0    None
# 1181        NaN      None  EN SERVICE       None        30.0    None
# 206         NaN  TROTTOIR  EN SERVICE       None         5.0    None
# 686         NaN  TROTTOIR  EN SERVICE       None         5.0    True
# 1732        NaN  TROTTOIR  EN SERVICE       None         5.0    True
# 752         NaN      None  PROVISOIRE       None        50.0    True
# 876         NaN      None  EN SERVICE       None        50.0    True
# 4773        NaN      None  EN SERVICE       None        50.0    True
# 997         NaN  CHAUSSEE  EN SERVICE       None        30.0    True
# 1035        NaN      None  EN SERVICE       None        50.0    True
# 1281        NaN  CHAUSSEE  EN SERVICE       None        30.0    True
# 1330        NaN  CHAUSSEE  EN SERVICE       None        30.0    None
# 1676        NaN  CHAUSSEE  EN SERVICE       None        50.0    True
# 1720        NaN  TROTTOIR  EN SERVICE       None         5.0    None
# 4428        NaN  TROTTOIR  EN SERVICE       None         5.0    None
# 2519        NaN  TROTTOIR  EN SERVICE       None         5.0    True
# 2683        NaN  CHAUSSEE  PROVISOIRE       None        50.0    True
# 2734        NaN  CHAUSSEE  EN SERVICE       None        30.0    None
# 2784        NaN      None  EN SERVICE       None        50.0    True
# 3264        NaN  CHAUSSEE  EN SERVICE       None        30.0    True
# 3457        NaN  CHAUSSEE  PROVISOIRE       None        30.0    None
# 4110        NaN  CHAUSSEE  EN SERVICE       None        30.0    True
# 4523        NaN  CHAUSSEE  EN SERVICE       None        30.0    True
# 4667        NaN  CHAUSSEE  PROVISOIRE       None        50.0    True
# 4923        NaN  CHAUSSEE  PROVISOIRE       None        50.0    None
# 5523        NaN  CHAUSSEE  EN SERVICE       None        30.0    True
#
#      d_service                                         geometry_y
# 159   inconnue  LINESTRING (651120.270 6858104.986, 651122.972...
# 1181  inconnue  LINESTRING (651120.270 6858104.986, 651122.972...
# 206   inconnue  LINESTRING (650446.301 6858749.672, 650449.892...
# 686   inconnue  LINESTRING (650838.787 6858233.662, 650830.493...
# 1732  inconnue  LINESTRING (650838.787 6858233.662, 650830.493...
# 752   inconnue  LINESTRING (650508.556 6858475.720, 650511.211...
# 876   inconnue  LINESTRING (650838.787 6858233.662, 650837.361...
# 4773  inconnue  LINESTRING (650838.787 6858233.662, 650837.361...
# 997   inconnue  LINESTRING (650935.359 6858639.153, 650943.365...
# 1035  inconnue  LINESTRING (649679.161 6858229.177, 649651.851...
# 1281  inconnue  LINESTRING (650307.011 6858392.357, 650304.691...
# 1330  inconnue  LINESTRING (649830.865 6858515.538, 649824.354...
# 1676  inconnue  LINESTRING (650581.645 6858875.992, 650579.839...
# 1720  inconnue  LINESTRING (649958.828 6858531.345, 649955.606...
# 4428  inconnue  LINESTRING (649958.828 6858531.345, 649955.606...
# 2519  inconnue  LINESTRING (651368.085 6858047.415, 651358.396...
# 2683  inconnue  LINESTRING (650645.341 6858957.045, 650654.245...
# 2734  inconnue  LINESTRING (650360.871 6858249.754, 650363.892...
# 2784  inconnue  LINESTRING (650477.344 6858354.483, 650475.119...
# 3264  inconnue  LINESTRING (650594.722 6858852.918, 650598.626...
# 3457  inconnue  LINESTRING (650566.206 6858857.142, 650554.113...
# 4110  inconnue  LINESTRING (651421.441 6858471.068, 651420.361...
# 4523  inconnue  LINESTRING (650891.996 6859055.872, 650885.724...
# 4667  inconnue  LINESTRING (650846.572 6858848.653, 650917.009...
# 4923  inconnue  LINESTRING (650460.830 6858915.452, 650447.145...
# 5523  inconnue  LINESTRING (650902.907 6858506.448, 650895.691...

# %%
for i, point in liste_df[3].iterrows():
    liste_df[3].at[i,"distance"] = liste_df_voie[3].distance(point.geometry).min()
    liste_df[3].at[i,"nearest_road"] = liste_df_voie[3].distance(point.geometry).idxmin()

liste_df[3]["nearest_road"] = liste_df[3]["nearest_road"].astype('int')

liste_merged.append((liste_df[3].merge(liste_df_voie[3], left_on='nearest_road', right_index=True)))

liste_merged[3]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
#
# 4346  2021  16:40    1  75    2    4    1    2         RUE DE LA GLACIERE
# 4565  2021  22:40    5  75    2    2    1    6     BOULEVARD DE L HOPITAL
# 4566  2021  19:40    1  75    2    3    1    3     BOULEVARD SAINT MARCEL
# 4623  2021  16:45    1  75    2    2    1    3         RUE DE LA GLACIERE
# 4646  2021  17:20    1  75    2    1    1    3                 RUE BUFFON
# 4647  2021  17:20    1  75    2    1    1    3                 RUE BUFFON
# 4752  2021  16:07    1  75    2    2    1    6     BOULEVARD SAINT MARCEL
# 5181  2021  12:50    1  75    2    2    1    3     BOULEVARD SAINT MARCEL
# 5051  2021  12:50    1  75    2    5    1    2            BOULEVARD ARAGO
#
#             lat  longitude  catr                       voie  v1   v2  circ  \
# 160   48.831887   2.355849     4     BOULEVARD DE L HOPITAL   0  NaN     2
# 3086  48.831881   2.355859     4             PLACE D ITALIE   0  NaN     2
# 193   48.836071   2.346694     4                  RUE BROCA   0  NaN     1
# 229   48.834866   2.343079     4            BOULEVARD ARAGO   0  NaN     2
# 286   48.848553   2.342158     4       PLACE DE LA SORBONNE   0  NaN     2
# 291   48.848262   2.364980     4          BOULEVARD MORLAND   0  NaN     2
# 2437  48.848939   2.364616     4          BOULEVARD MORLAND   0  NaN     1
# 382   48.843380   2.342505     4             RUE GAY LUSSAC   0  NaN     2
# 427   48.836803   2.351867     4     BOULEVARD SAINT MARCEL   0  NaN     2
# 525   48.832269   2.362794     4              RUE NATIONALE   0  NaN     2
# 608   48.834558   2.357800     4     BOULEVARD DE L HOPITAL   0  NaN     2
# 684   48.837694   2.345507     4    BOULEVARD DE PORT ROYAL   0  NaN     2
# 824   48.847120   2.364974     4              QUAI HENRI IV   0  NaN     2
# 825   48.847120   2.364974     4              QUAI HENRI IV   0  NaN     2
# 3787  48.847367   2.364763     4              QUAI HENRI IV   0  NaN    -1
# 833   48.848899   2.347463     4             RUE DES CARMES   0  NaN     1
# 919   48.836567   2.351175     4            BOULEVARD ARAGO   0  NaN     1
# 1354  48.844234   2.364770     4            PLACE VALHUBERT   0  NaN     2
# 1470  48.838850   2.360986     4     BOULEVARD DE L HOPITAL   0  NaN     2
# 2786  48.838758   2.360923     4     BOULEVARD DE L HOPITAL   0  NaN     3
# 1508  48.832861   2.355540     4  RUE PHILIPPE DE CHAMPAGNE   0  NaN     2
# 1946  48.846800   2.343347     4               RUE SOUFFLOT   0  NaN     2
# 2092  48.840275   2.346033     4         RUE CLAUDE BERNARD   0  NaN     2
# 2188  48.846916   2.342840     4               RUE SOUFFLOT   0  NaN     2
# 2273  48.839708   2.356596     4               RUE POLIVEAU   0  NaN     1
# 2576  48.849593   2.344873     4          RUE SAINT JACQUES   0  NaN     1
# 3071  48.846991   2.353836     4                RUE JUSSIEU   0  NaN     2
# 4241  48.846858   2.354044     4                RUE JUSSIEU   0  NaN     2
# 5505  48.847406   2.352815     4                RUE JUSSIEU   0  NaN     2
# 2589  48.849393   2.356807     4         QUAI SAINT BERNARD   0  NaN     2
# 2590  48.846855   2.360967     4         QUAI SAINT BERNARD   0  NaN     2
# 5531  POINT (653104.225 6860945.345)    1.498520         74301
# 2766  POINT (652548.273 6859562.019)    0.323546         74892
# 2785  POINT (651920.203 6859633.468)    0.280275         74693
# 2990  POINT (652529.080 6860068.789)    0.180114        284129
# 3134  POINT (651783.019 6859202.721)    5.570789         85843
# 3188  POINT (652162.678 6859706.186)    1.422686        284097
# 3453  POINT (653342.530 6860536.216)    4.838997        224657
# 4057  POINT (653155.808 6860181.447)   10.453070        192426
# 4345  POINT (653342.371 6860691.050)   15.045727        118141
# 4346  POINT (651871.834 6859271.261)    0.899114         70572
# 4565  POINT (652782.962 6859427.556)    0.147460        284733
# 4566  POINT (652515.768 6859868.410)    0.175259        224663
# 4623  POINT (651920.289 6859635.024)    1.649601         34251
# 4646  POINT (653171.933 6860487.442)    0.129466        215667
# 4647  POINT (653171.933 6860487.442)    0.129466        215667
# 4752  POINT (652806.847 6860016.815)    7.740729        224664
# 5181  POINT (652806.698 6860007.587)    0.497057        224664
# 5051  POINT (652425.790 6859834.454)    1.272384        290599
#
#                id_local     id_osm code_com_d             ame_d  \
# 160   geovelo_773814788  773814788      75113  COULOIR BUS+VELO
# 3086  geovelo_773814788  773814788      75113  COULOIR BUS+VELO
# 193     geovelo_4081744    4081744      75113             AUCUN
# 229   geovelo_874404604  874404604      75113    PISTE CYCLABLE
# 286   geovelo_705282786  705282786      75105    PISTE CYCLABLE
# 291   geovelo_294809904  294809904      75104    PISTE CYCLABLE
# 2437  geovelo_294809904  294809904      75104    PISTE CYCLABLE
# 382    geovelo_37106047   37106047      75105             AUCUN
# 427   geovelo_627403915  627403915      75113  COULOIR BUS+VELO
# 525   geovelo_606366022  606366022      75113    PISTE CYCLABLE
# 608    geovelo_43904125   43904125      75113             AUCUN
# 684    geovelo_85320921   85320921      75113  COULOIR BUS+VELO
# 824   geovelo_444383821  444383821      75104    PISTE CYCLABLE
# 825   geovelo_444383821  444383821      75104    PISTE CYCLABLE
# 3787  geovelo_444383821  444383821      75104    PISTE CYCLABLE
# 833     geovelo_4217080    4217080      75105             AUCUN
# 919   geovelo_548078038  548078038      75113    PISTE CYCLABLE
# 1354  geovelo_756600293  756600293      75105    PISTE CYCLABLE
# 1470  geovelo_570738517  570738517      75113             AUCUN
# 2786  geovelo_570738517  570738517      75113             AUCUN
# 1508   geovelo_56668442   56668442      75113             AUCUN
# 1946  geovelo_589489441  589489441      75105    PISTE CYCLABLE
# 2092   geovelo_85068499   85068499      75105             AUCUN
# 2188    geovelo_4217072    4217072      75105             AUCUN
# 2273    geovelo_3630516    3630516      75105             AUCUN
# 2576   geovelo_34322419   34322419      75105             AUCUN
# 3071   geovelo_34322419   34322419      75105             AUCUN
# 4241   geovelo_34322419   34322419      75105             AUCUN
# 5505   geovelo_34322419   34322419      75105             AUCUN
# 2589   geovelo_85076169   85076169      75105  COULOIR BUS+VELO
# 2590   geovelo_28208667   28208667      75105  COULOIR BUS+VELO
# 5503   geovelo_28208667   28208667      75105  COULOIR BUS+VELO
# 5504   geovelo_28208667   28208667      75105  COULOIR BUS+VELO
# 5531   geovelo_28208667   28208667      75105  COULOIR BUS+VELO
# 2766   geovelo_53799097   53799097      75113  COULOIR BUS+VELO
# 2785  geovelo_932810317  932810317      75113  COULOIR BUS+VELO
# 2990  geovelo_100895617  100895617      75105             AUCUN
# 3134  geovelo_256339821  256339821      75113    PISTE CYCLABLE
# 3188    geovelo_6022630    6022630      75113             AUCUN
# 3453  geovelo_674703656  674703656      75113  COULOIR BUS+VELO
# 4057   geovelo_41469916   41469916      75113  COULOIR BUS+VELO
# 4345   geovelo_31831464   31831464      75105    PISTE CYCLABLE
# 4346   geovelo_11288511   11288511      75113             AUCUN
# 4565   geovelo_48670609   48670609      75113             AUCUN
# 4566   geovelo_31830587   31830587      75113  COULOIR BUS+VELO
# 4623  geovelo_874404606  874404606      75113    PISTE CYCLABLE
# 4646    geovelo_4039546    4039546      75105             AUCUN
# 4647    geovelo_4039546    4039546      75105             AUCUN
# 4752   geovelo_85076166   85076166      75113  COULOIR BUS+VELO
# 5181   geovelo_85076166   85076166      75113  COULOIR BUS+VELO
# 5051   geovelo_25485138   25485138      75105             AUCUN
#
#               regime_d           sens_d  largeur_d   local_d    statut_d  \
# 160               None  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 3086              None  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 193   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 229              AUTRE  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 286   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 291              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 2437             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 382            ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 427              AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 525              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 608   EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 684              AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 824              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 825              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 3787             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 833            ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 919              AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 1354             AUTRE  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1470  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2786  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1508           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 1946  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  PROVISOIRE
# 2092  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2188  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2273           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2576  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 3071  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4241  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 5505  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 2589  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2590  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5503  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5504  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5531  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2766  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2785  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2990           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 3134             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 3188           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 3453             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 4057             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 4345             AUTRE  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
# 4346           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4565           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4566             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 4623             AUTRE  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4646           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4647           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 4752             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5181             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5051  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN      None  EN SERVICE
#
#      code_com_g                       ame_g          regime_g  \
# 160       75113                       AUCUN              None
# 3086      75113                       AUCUN              None
# 193       75113  DOUBLE SENS CYCLABLE BANDE  EN AGGLOMERATION
# 229       75113                       AUCUN              None
# 286       75105                       AUCUN              None
# 291       75104              PISTE CYCLABLE             AUTRE
# 2437      75104              PISTE CYCLABLE             AUTRE
# 382       75105  DOUBLE SENS CYCLABLE BANDE           ZONE 30
# 427       75113            COULOIR BUS+VELO             AUTRE
# 525       75113                       AUCUN              None
# 608       75113            COULOIR BUS+VELO  EN AGGLOMERATION
# 684       75113            COULOIR BUS+VELO             AUTRE
# 824       75104              PISTE CYCLABLE             AUTRE
# 825       75104              PISTE CYCLABLE             AUTRE
# 3787      75104              PISTE CYCLABLE             AUTRE
# 833       75105        DOUBLE SENS CYCLABLE           ZONE 30
# 919       75113                       AUCUN              None
# 1354      75105              PISTE CYCLABLE             AUTRE
# 1470      75113              BANDE CYCLABLE  EN AGGLOMERATION
# 2786      75113              BANDE CYCLABLE  EN AGGLOMERATION
# 1508      75113        DOUBLE SENS CYCLABLE           ZONE 30
# 1946      75105                       AUCUN              None
# 2092      75105              PISTE CYCLABLE  EN AGGLOMERATION
# 2188      75105        DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 2273      75105        DOUBLE SENS CYCLABLE           ZONE 30
# 2576      75105            COULOIR BUS+VELO  EN AGGLOMERATION
# 3071      75105            COULOIR BUS+VELO  EN AGGLOMERATION
# 4241      75105            COULOIR BUS+VELO  EN AGGLOMERATION
# 5505      75105            COULOIR BUS+VELO  EN AGGLOMERATION
# 2589      75105                       AUCUN              None
# 2590      75105                       AUCUN  EN AGGLOMERATION
# 5503      75105                       AUCUN  EN AGGLOMERATION
# 5504      75105                       AUCUN  EN AGGLOMERATION
# 5531      75105                       AUCUN  EN AGGLOMERATION
# 2766      75113            COULOIR BUS+VELO  EN AGGLOMERATION
# 2785      75113            COULOIR BUS+VELO  EN AGGLOMERATION
# 2990      75105        DOUBLE SENS CYCLABLE           ZONE 30
# 3134      75113                       AUCUN              None
# 3188      75113        DOUBLE SENS CYCLABLE           ZONE 30
# 3453      75113            COULOIR BUS+VELO             AUTRE
# 4057      75113            COULOIR BUS+VELO             AUTRE
# 4345      75105              PISTE CYCLABLE             AUTRE
# 4346      75113        DOUBLE SENS CYCLABLE           ZONE 30
# 4565      75113        DOUBLE SENS CYCLABLE           ZONE 30
# 4566      75113            COULOIR BUS+VELO             AUTRE
# 4623      75113                       AUCUN              None
# 4646      75105  DOUBLE SENS CYCLABLE BANDE           ZONE 30
# 4647      75105  DOUBLE SENS CYCLABLE BANDE           ZONE 30
# 4752      75113            COULOIR BUS+VELO             AUTRE
# 5181      75113            COULOIR BUS+VELO             AUTRE
# 5051      75105            COULOIR BUS+VELO  EN AGGLOMERATION
#
#                sens_g  largeur_g   local_g    statut_g access_ame  trafic_vit  \
# 160              None        NaN      None  EN SERVICE       None         NaN
# 3086             None        NaN      None  EN SERVICE       None         NaN
# 193   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 229              None        NaN      None  EN SERVICE       None         5.0
# 286              None        NaN      None  PROVISOIRE       None        30.0
# 291   UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 2437  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 382   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 427   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 525              None        NaN  TROTTOIR  EN SERVICE       None         5.0
# 608   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 684   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 824   UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 825   UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 3787  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 833   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 919              None        NaN  TROTTOIR  EN SERVICE       None         5.0
# 1354  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# 1470  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2786  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 1508  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 1946             None        NaN      None  PROVISOIRE       None        50.0
# 2092  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2188  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2273  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 2576  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 3071  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 4241  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 5505  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2589             None        NaN      None  EN SERVICE       None        50.0
# 2590  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None        50.0
# 5503  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None        50.0
# 5504  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None        50.0
# 5531  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None        50.0
# 2766  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2785  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 2990  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 3134             None        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 3188  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 3453  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 4057  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 4345  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None         5.0
# 4346  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 4565  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 4566  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 4623             None        NaN      None  EN SERVICE       None         5.0
# 4646  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 4647  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 4752  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 5181  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None         5.0
# 5051  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
#
#      lumiere d_service                                         geometry_y
# 160     None  inconnue  LINESTRING (652711.954 6859281.834, 652699.283...
# 3086    None  inconnue  LINESTRING (652711.954 6859281.834, 652699.283...
# 193     True  inconnue  LINESTRING (651939.844 6859780.152, 651945.266...
# 229     None  inconnue  LINESTRING (651671.198 6859619.205, 651680.977...
# 286     True  inconnue  LINESTRING (651627.396 6861012.105, 651639.272...
# 291     None  inconnue  LINESTRING (653328.984 6861253.739, 653369.311...
# 4752    None  inconnue  LINESTRING (652795.229 6860002.577, 652809.592...
# 5181    None  inconnue  LINESTRING (652795.229 6860002.577, 652809.592...
# 5051    True  inconnue  LINESTRING (652400.170 6859888.840, 652401.410...

# %%
for i, point in liste_df[4].iterrows():
    liste_df[4].at[i,"distance"] = liste_df_voie[4].distance(point.geometry).min()
    liste_df[4].at[i,"nearest_road"] = liste_df_voie[4].distance(point.geometry).idxmin()

liste_df[4]["nearest_road"] = liste_df[4]["nearest_road"].astype('int')

liste_merged.append((liste_df[4].merge(liste_df_voie[4], left_on='nearest_road', right_index=True)))

liste_merged[4]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/shapely/measurement.py:74: RuntimeWarning: invalid value encountered in distance
#   return lib.distance(a, b, **kwargs)
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 134   202100002046     1     1    0     2     1     1      5    20    12
# 147   202100002265     1     1    0     2     3     1      5    18    12
# 510   202100007334     2     1    0     2     1     1      5    19    11
# 2496  202100027566     1     1    0     2     0     1      5    21     7
# 2550  202100027966     1     1    0     2     4     2      5    20     7
# ...            ...   ...   ...  ...   ...   ...   ...    ...   ...   ...
# 5411  202100053628     2     1    0     2     8     1      5    26     1
# 5495  202100054787     2     1    0     2     3     1      5    16     1
# 5550  202100055529     1     1    0     1     1     1      5    10     1
# 5506  202100054924     2     1    0     2     3    18      5    15     1
# 5509  202100054927     2     1    0     0     1     7      5    15     1
#
#         an   hrmn  lum dep  agg  int  atm  col                       adr  \
# 134   2021  13:45    1  75    2    4    1    3        BOULEVARD VOLTAIRE
# 147   2021  12:45    1  75    2    3    1    3  BOULEVARD DE LA VILLETTE
# 510   2021  19:45    5  75    2    7    1    2    AVENUE MATHURIN MOREAU
# 2496  2021  21:35    2  75    2    1    1    3  BOULEVARD DE LA VILLETTE
# 2550  2021  19:10    1  75    2    7    1    4   PLACE DU COLONEL FABIEN
# ...    ...    ...  ...  ..  ...  ...  ...  ...                       ...
# 5411  2021  08:10    2  75    2    2    1    3        BOULEVARD VOLTAIRE
# 5495  2021  14:50    1  75    2    1    4    3       AVENUE LEDRU ROLLIN
# 5550  2021  19:50    5  75    2    4    1    6       AVENUE LEDRU ROLLIN
# 5506  2021  21:01    5  75    2    2    1    3         AVENUE PARMENTIER
# 5509  2021  17:13    1  75    2    4    1    7        BOULEVARD HENRI IV
#
#             lat  longitude  catr                      voie  v1   v2  circ  \
# 134   48.862383   2.372528     4        BOULEVARD VOLTAIRE   0  NaN     4
# 147   48.874382   2.374501     4  BOULEVARD DE LA VILLETTE   0  NaN     3
# 510   48.878021   2.370690     4    AVENUE MATHURIN MOREAU   0  NaN     2
# 2496  48.877459   2.370989     4  BOULEVARD DE LA VILLETTE   0  NaN     1
# 2550  48.877745   2.370135     4   PLACE DU COLONEL FABIEN   0  NaN     1
# ...         ...        ...   ...                       ...  ..  ...   ...
# 5411  48.862132   2.372856     4        BOULEVARD VOLTAIRE   0  NaN     2
# 5495  48.854299   2.377877     4       AVENUE LEDRU ROLLIN   0  NaN     2
# 5550  48.854513   2.378030     4       AVENUE LEDRU ROLLIN   0  NaN     2
# 5506  48.871236   2.370145     4         AVENUE PARMENTIER   0  NaN     2
# 5509  48.852222   2.366028     4        BOULEVARD HENRI IV   0  NaN     2
#
#       nbv  vosp  prof   pr  pr1  plan lartpc larrout  surf  infra  situ  vma  \
# 134     4     1     1  (1)  (1)     2    NaN      -1     1     -1     5   30
# 147     2     1     1  (1)  (1)     1    NaN      -1     1     -1     5   30
# 510     2     0     2  (1)  (1)     1    NaN      -1     1      0     1   30
# 2496    1     1     1  (1)  (1)     1    NaN      -1     1      0     1   50
# 2550    3     0     1  (1)  (1)     1    NaN      -1     1      0     1   50
# ...   ...   ...   ...  ...  ...   ...    ...     ...   ...    ...   ...  ...
# 5411    2     1     1  (1)  (1)     1    NaN      -1     1     -1     5   50
# 5495    2     0     1  (1)  (1)     1    NaN      -1     5      0     1   30
# 5550    2     0     1  (1)  (1)     1    NaN      -1     1      0     1   50
# 5506    3     0     2  (1)  (1)     1    NaN      -1     1      0     1   30
# 5509    4     3     1  (1)  (1)     1    NaN      -1     1     -1     6   50
#
#                           geometry_x   distance  nearest_road  \
# 134   POINT (653965.625 6862666.237)   1.759401         31777
# 147   POINT (654120.940 6863999.290)   4.055263         35877
# 510   POINT (653844.642 6864406.144)  26.490426         35877
# 2496  POINT (653866.073 6864343.479)   2.658299         35877
# 2550  POINT (653803.693 6864375.779)  36.912418         35877
# ...                              ...        ...           ...
# 5411  POINT (653989.467 6862638.137)   6.478624         31399
# 5495  POINT (654350.964 6861764.258)  20.084456        288880
# 5550  POINT (654362.408 6861787.940)   1.419036        288880
# 5506  POINT (653798.653 6863652.016)   1.520361        288874
# 5509  POINT (653479.693 6861540.229)   1.178435         55062
#
#                id_local     id_osm code_com_d           ame_d  \
# 134   geovelo_606430537  606430537      75111  PISTE CYCLABLE
# 147    geovelo_52719941   52719941      75119  PISTE CYCLABLE
# 510    geovelo_52719941   52719941      75119  PISTE CYCLABLE
# 2496   geovelo_52719941   52719941      75119  PISTE CYCLABLE
# 2550   geovelo_52719941   52719941      75119  PISTE CYCLABLE
# ...                 ...        ...        ...             ...
# 5411  geovelo_577275849  577275849      75111  PISTE CYCLABLE
# 5495    geovelo_8059156    8059156      75111           AUCUN
# 5550    geovelo_8059156    8059156      75111           AUCUN
# 5506   geovelo_23695896   23695896      75110           AUCUN
# 5509  geovelo_390294218  390294218      75104  BANDE CYCLABLE
#
#               regime_d           sens_d  largeur_d   local_d    statut_d  \
# 134              AUTRE  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 147              AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 510              AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2496             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 2550             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# ...                ...              ...        ...       ...         ...
# 5411             AUTRE  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 5495           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 5550           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 5506           ZONE 30  UNIDIRECTIONNEL        NaN      None  EN SERVICE
# 5509  EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
#
#      code_com_g                 ame_g regime_g           sens_g  largeur_g  \
# 134       75111                 AUCUN     None             None        NaN
# 147       75119                 AUCUN     None             None        NaN
# 510       75119                 AUCUN     None             None        NaN
# 2496      75119                 AUCUN     None             None        NaN
# 2550      75119                 AUCUN     None             None        NaN
# ...         ...                   ...      ...              ...        ...
# 5411      75111                 AUCUN     None             None        NaN
# 5495      75111  DOUBLE SENS CYCLABLE  ZONE 30  UNIDIRECTIONNEL        NaN
# 5550      75111  DOUBLE SENS CYCLABLE  ZONE 30  UNIDIRECTIONNEL        NaN
# 5506      75110  DOUBLE SENS CYCLABLE  ZONE 30  UNIDIRECTIONNEL        NaN
# 5509      75104                 AUCUN     None             None        NaN
#
#        local_g    statut_g access_ame  trafic_vit lumiere d_service  \
# 134       None  EN SERVICE       None         5.0    None  inconnue
# 147   CHAUSSEE  EN SERVICE       None         5.0    None  inconnue
# 510   CHAUSSEE  EN SERVICE       None         5.0    None  inconnue
# 2496  CHAUSSEE  EN SERVICE       None         5.0    None  inconnue
# 2550  CHAUSSEE  EN SERVICE       None         5.0    None  inconnue
# ...        ...         ...        ...         ...     ...       ...
# 5411  CHAUSSEE  EN SERVICE       None         5.0    None  inconnue
# 5495  CHAUSSEE  EN SERVICE       None        30.0    None  inconnue
# 5550  CHAUSSEE  EN SERVICE       None        30.0    None  inconnue
# 5506  CHAUSSEE  EN SERVICE       None        30.0    None  inconnue
# 5509      None  EN SERVICE       None        50.0    None  inconnue
#
#                                              geometry_y
# 134   LINESTRING (653977.795 6862657.600, 653965.382...
# 147   LINESTRING (654306.237 6863746.969, 654301.856...
# 510   LINESTRING (654306.237 6863746.969, 654301.856...
# 2496  LINESTRING (654306.237 6863746.969, 654301.856...
# 2550  LINESTRING (654306.237 6863746.969, 654301.856...
# ...                                                 ...
# 5411  LINESTRING (653922.517 6862690.610, 653957.392...
# 5495  LINESTRING (654412.662 6861652.496, 654409.502...
# 5550  LINESTRING (654412.662 6861652.496, 654409.502...
# 5506  LINESTRING (653933.120 6863711.905, 653927.629...
# 5509  LINESTRING (653440.046 6861521.177, 653444.257...
#
# [136 rows x 62 columns]

# %%
for i, point in liste_df[5].iterrows():
    liste_df[5].at[i,"distance"] = liste_df_voie[5].distance(point.geometry).min()
    liste_df[5].at[i,"nearest_road"] = liste_df_voie[5].distance(point.geometry).idxmin()

liste_df[5]["nearest_road"] = liste_df[5]["nearest_road"].astype('int')

liste_merged.append((liste_df[5].merge(liste_df_voie[5], left_on='nearest_road', right_index=True)))

len(liste_merged)
# Out:
# 6

# %%
liste_merged[5]
# Out:
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 68    202100000780     2     1    0     2     1     1      5    31    12
# 3073  202100033079     2     1    0     2     1     5      5    20     6
#
#         an   hrmn  lum dep  agg  int  atm  col                     adr  \
# 68    2021  10:07    1  75    2    2    1    3  AVENUE CORENTIN CARIOU
# 3073  2021  21:15    1  75    2    3    1    1      QUAI DE LA GIRONDE
#
#             lat  longitude  catr                    voie  v1   v2  circ  nbv  \
# 68    48.898194   2.386009     4  AVENUE CORENTIN CARIOU   0  NaN     1    3
# 3073  48.892489   2.385553     4      QUAI DE LA GIRONDE   0  NaN     1    1
#
#       vosp  prof   pr  pr1  plan lartpc larrout  surf  infra  situ  vma  \
# 68       1     1  (1)  (1)     1    NaN      -1     1      0     1   30
# 3073     1     1  (1)  (1)     2    NaN      -1     2      0     1   30
#
#                           geometry_x  distance  nearest_road  \
# 68    POINT (654985.600 6866640.432)  0.252026         81995
# 3073  POINT (654947.233 6866006.321)  4.594885         90096
#
#                id_local     id_osm code_com_d           ame_d  \
# 68    geovelo_632262545  632262545      75119  BANDE CYCLABLE
# 3073   geovelo_76607825   76607825      75119  PISTE CYCLABLE
#
#               regime_d           sens_d  largeur_d   local_d    statut_d  \
# 68    EN AGGLOMERATION  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE
# 3073           ZONE 30  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE
#
#      code_com_g           ame_g regime_g           sens_g  largeur_g  \
# 68        75119           AUCUN     None             None        NaN
# 3073      75119  PISTE CYCLABLE  ZONE 30  UNIDIRECTIONNEL        NaN
#
#        local_g    statut_g access_ame  trafic_vit lumiere d_service  \
# 68        None  EN SERVICE       None        50.0    True  inconnue
# 3073  TROTTOIR  EN SERVICE       None        30.0    None  inconnue
#
#                                              geometry_y
# 68    LINESTRING (654998.850 6866656.653, 654985.656...
# 3073  LINESTRING (654941.299 6865987.252, 654946.521...

# %% [markdown]
# ## On merge tous les datasets

# %%
final_df_merged = pd.concat([liste_merged[0],liste_merged[1],liste_merged[2],liste_merged[3],liste_merged[4],liste_merged[5]])
final_df_merged
# Out:
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 2885  202100031333     2     1    1     0     2     1      5     2     7
# 3814  202100039165     1     1    0     2     8     1      6    19     5
# 263   202100003857     1     1    0     1     3     1      5     9    12
# 1033  202100013414     0     1    0     2     1     1      5    13    10
# 1678  202100019528     2     1    0     2     1     1      5    11     9
# ...            ...   ...   ...  ...   ...   ...   ...    ...   ...   ...
# 5550  202100055529     1     1    0     1     1     1      5    10     1
# 5506  202100054924     2     1    0     2     3    18      5    15     1
# 5509  202100054927     2     1    0     0     1     7      5    15     1
# 68    202100000780     2     1    0     2     1     1      5    31    12
# 3073  202100033079     2     1    0     2     1     5      5    20     6
#
#         an   hrmn  lum dep  agg  int  atm  col                           adr  \
# 2885  2021  18:40    1  92    2    1    1    3           LAZARE CARNOT (RUE)
# 3814  2021  15:06    1  92    2    1    2    3  VANVES BOULEVARD DE N° PAIRS
# 263   2021  10:11    1  92    2    1    1    6          PELLETAN RUE CAMILLE
# 1033  2021  11:20    1  92    2    3    1    3      PIERRE LAROUSSE (AVENUE)
# 1678  2021  18:43    1  92    2    1    1    3                 RAYMOND DAVID
# ...    ...    ...  ...  ..  ...  ...  ...  ...                           ...
# 5550  2021  19:50    5  75    2    4    1    6           AVENUE LEDRU ROLLIN
# 5506  2021  21:01    5  75    2    2    1    3             AVENUE PARMENTIER
# 5509  2021  17:13    1  75    2    4    1    7            BOULEVARD HENRI IV
# 68    2021  10:07    1  75    2    2    1    3        AVENUE CORENTIN CARIOU
# 3073  2021  21:15    1  75    2    3    1    1            QUAI DE LA GIRONDE
#
#             lat  longitude  catr                    voie  v1   v2  circ  nbv  \
# 2885  48.809490   2.271230     4                     NaN   0  NaN     2    2
# 3814  48.809930   2.282590     3                      72   0  NaN     2    2
# 263   48.816749   2.309465     4                     NaN   0  NaN     1    1
# 1033  48.819554   2.306153     3                      50   0  NaN    -1    1
# 1678  48.816288   2.295262     3                      63   0  NaN     2    2
# ...         ...        ...   ...                     ...  ..  ...   ...  ...
# 5550  48.854513   2.378030     4     AVENUE LEDRU ROLLIN   0  NaN     2    2
# 5506  48.871236   2.370145     4       AVENUE PARMENTIER   0  NaN     2    3
# 5509  48.852222   2.366028     4      BOULEVARD HENRI IV   0  NaN     2    4
# 68    48.898194   2.386009     4  AVENUE CORENTIN CARIOU   0  NaN     1    3
# 3073  48.892489   2.385553     4      QUAI DE LA GIRONDE   0  NaN     1    1
#
#       vosp  prof   pr  pr1  plan lartpc larrout  surf  infra  situ  vma  \
# 2885     0     1    0    0     1    NaN      -1     1      0     1   30
# 3814     0     1    0    1     1    NaN      -1     2      0     1   50
# 263      0     1    0    0     1    NaN      -1     1      0     1   30
# 1033     0     1    0    0     1    NaN      -1     1      0     1   50
# 1678     0     1    0    0     1    NaN      -1     1      0     1   50
# ...    ...   ...  ...  ...   ...    ...     ...   ...    ...   ...  ...
# 5550     0     1  (1)  (1)     1    NaN      -1     1      0     1   50
# 5506     0     2  (1)  (1)     1    NaN      -1     1      0     1   30
# 5509     3     1  (1)  (1)     1    NaN      -1     1     -1     6   50
# 68       1     1  (1)  (1)     1    NaN      -1     1      0     1   30
# 3073     1     1  (1)  (1)     2    NaN      -1     2      0     1   30
#
#                           geometry_x    distance  nearest_road  \
# 2885  POINT (646479.832 6856848.981)   41.276557        286435
# 3814  POINT (647314.520 6856890.263)  148.441738        167205
# 263   POINT (649294.766 6857630.845)   80.140361        166823
# 1033  POINT (649054.277 6857944.809)   56.617679        286266
# 1678  POINT (648251.446 6857588.836)    6.624460        253512
# ...                              ...         ...           ...
# 5550  POINT (654362.408 6861787.940)    1.419036        288880
# 5506  POINT (653798.653 6863652.016)    1.520361        288874
# 5509  POINT (653479.693 6861540.229)    1.178435         55062
# 68    POINT (654985.600 6866640.432)    0.252026         81995
# 3073  POINT (654947.233 6866006.321)    4.594885         90096
#
#                id_local     id_osm code_com_d  \
# 2885   geovelo_37655991   37655991      92023
# 3814  geovelo_755707363  755707363      92020
# 263   geovelo_659513577  659513577      92049
# 1033   geovelo_25396506   25396506      92046
# 1678  geovelo_540065626  540065626      92046
# ...                 ...        ...        ...
# 5550    geovelo_8059156    8059156      75111
# 5506   geovelo_23695896   23695896      75110
# 5509  geovelo_390294218  390294218      75104
# 68    geovelo_632262545  632262545      75119
# 3073   geovelo_76607825   76607825      75119
#
#                                                ame_d          regime_d  \
# 2885                                           AUCUN  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 263                                            AUCUN  EN AGGLOMERATION
# 1033                                           AUCUN  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# ...                                              ...               ...
# 5550                                           AUCUN           ZONE 30
# 5506                                           AUCUN           ZONE 30
# 5509                                  BANDE CYCLABLE  EN AGGLOMERATION
# 68                                    BANDE CYCLABLE  EN AGGLOMERATION
# 3073                                  PISTE CYCLABLE           ZONE 30
#
#                sens_d  largeur_d   local_d    statut_d code_com_g  \
# 2885  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92023
# 3814  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92020
# 263   UNIDIRECTIONNEL        NaN      None  EN SERVICE      92049
# 1033  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# ...               ...        ...       ...         ...        ...
# 5550  UNIDIRECTIONNEL        NaN      None  EN SERVICE      75111
# 5506  UNIDIRECTIONNEL        NaN      None  EN SERVICE      75110
# 5509  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      75104
# 68    UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      75119
# 3073  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE      75119
#
#                                                ame_g          regime_g  \
# 2885                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 263                                   BANDE CYCLABLE  EN AGGLOMERATION
# 1033                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# ...                                              ...               ...
# 5550                            DOUBLE SENS CYCLABLE           ZONE 30
# 5506                            DOUBLE SENS CYCLABLE           ZONE 30
# 5509                                           AUCUN              None
# 68                                             AUCUN              None
# 3073                                  PISTE CYCLABLE           ZONE 30
#
#                sens_g  largeur_g   local_g    statut_g access_ame  trafic_vit  \
# 2885  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 3814  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# 263   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 1033  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# ...               ...        ...       ...         ...        ...         ...
# 5550  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 5506  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 5509             None        NaN      None  EN SERVICE       None        50.0
# 68               None        NaN      None  EN SERVICE       None        50.0
# 3073  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None        30.0
#
#      lumiere d_service                                         geometry_y
# 2885    None  inconnue  LINESTRING (646440.773 6856862.329, 646438.830...
# 3814    None  inconnue  LINESTRING (647271.267 6856742.089, 647274.993...
# 263     True  inconnue  LINESTRING (649246.431 6857566.922, 649242.525...
# 1033    True  inconnue  LINESTRING (649024.597 6857993.023, 649030.113...
# 1678    True  inconnue  LINESTRING (648264.439 6857585.820, 648257.143...
# ...      ...       ...                                                ...
# 5550    None  inconnue  LINESTRING (654412.662 6861652.496, 654409.502...
# 5506    None  inconnue  LINESTRING (653933.120 6863711.905, 653927.629...
# 5509    None  inconnue  LINESTRING (653440.046 6861521.177, 653444.257...
# 68      True  inconnue  LINESTRING (654998.850 6866656.653, 654985.656...
# 3073    None  inconnue  LINESTRING (654941.299 6865987.252, 654946.521...
#
# [229 rows x 62 columns]

# %%
final_df_merged['count_accidents'] = 1
final_df_merged
# Out:
#            Num_Acc  senc  catv  obs  obsm  choc  manv  motor  jour  mois  \
# 2885  202100031333     2     1    1     0     2     1      5     2     7
# 3814  202100039165     1     1    0     2     8     1      6    19     5
# 263   202100003857     1     1    0     1     3     1      5     9    12
# 1033  202100013414     0     1    0     2     1     1      5    13    10
# 1678  202100019528     2     1    0     2     1     1      5    11     9
# ...            ...   ...   ...  ...   ...   ...   ...    ...   ...   ...
# 5550  202100055529     1     1    0     1     1     1      5    10     1
# 5506  202100054924     2     1    0     2     3    18      5    15     1
# 5509  202100054927     2     1    0     0     1     7      5    15     1
# 68    202100000780     2     1    0     2     1     1      5    31    12
# 3073  202100033079     2     1    0     2     1     5      5    20     6
#
#         an   hrmn  lum dep  agg  int  atm  col                           adr  \
# 2885  2021  18:40    1  92    2    1    1    3           LAZARE CARNOT (RUE)
# 3814  2021  15:06    1  92    2    1    2    3  VANVES BOULEVARD DE N° PAIRS
# 263   2021  10:11    1  92    2    1    1    6          PELLETAN RUE CAMILLE
# 1033  2021  11:20    1  92    2    3    1    3      PIERRE LAROUSSE (AVENUE)
# 1678  2021  18:43    1  92    2    1    1    3                 RAYMOND DAVID
# ...    ...    ...  ...  ..  ...  ...  ...  ...                           ...
# 5550  2021  19:50    5  75    2    4    1    6           AVENUE LEDRU ROLLIN
# 5506  2021  21:01    5  75    2    2    1    3             AVENUE PARMENTIER
# 5509  2021  17:13    1  75    2    4    1    7            BOULEVARD HENRI IV
# 68    2021  10:07    1  75    2    2    1    3        AVENUE CORENTIN CARIOU
# 3073  2021  21:15    1  75    2    3    1    1            QUAI DE LA GIRONDE
#
#             lat  longitude  catr                    voie  v1   v2  circ  nbv  \
# 2885  48.809490   2.271230     4                     NaN   0  NaN     2    2
# 3814  48.809930   2.282590     3                      72   0  NaN     2    2
# 263   48.816749   2.309465     4                     NaN   0  NaN     1    1
# 1033  48.819554   2.306153     3                      50   0  NaN    -1    1
# 1678  48.816288   2.295262     3                      63   0  NaN     2    2
# ...         ...        ...   ...                     ...  ..  ...   ...  ...
# 5550  48.854513   2.378030     4     AVENUE LEDRU ROLLIN   0  NaN     2    2
# 5506  48.871236   2.370145     4       AVENUE PARMENTIER   0  NaN     2    3
# 5509  48.852222   2.366028     4      BOULEVARD HENRI IV   0  NaN     2    4
# 68    48.898194   2.386009     4  AVENUE CORENTIN CARIOU   0  NaN     1    3
# 3073  48.892489   2.385553     4      QUAI DE LA GIRONDE   0  NaN     1    1
#
#       vosp  prof   pr  pr1  plan lartpc larrout  surf  infra  situ  vma  \
# 2885     0     1    0    0     1    NaN      -1     1      0     1   30
# 3814     0     1    0    1     1    NaN      -1     2      0     1   50
# 263      0     1    0    0     1    NaN      -1     1      0     1   30
# 1033     0     1    0    0     1    NaN      -1     1      0     1   50
# 1678     0     1    0    0     1    NaN      -1     1      0     1   50
# ...    ...   ...  ...  ...   ...    ...     ...   ...    ...   ...  ...
# 5550     0     1  (1)  (1)     1    NaN      -1     1      0     1   50
# 5506     0     2  (1)  (1)     1    NaN      -1     1      0     1   30
# 5509     3     1  (1)  (1)     1    NaN      -1     1     -1     6   50
# 68       1     1  (1)  (1)     1    NaN      -1     1      0     1   30
# 3073     1     1  (1)  (1)     2    NaN      -1     2      0     1   30
#
#                           geometry_x    distance  nearest_road  \
# 2885  POINT (646479.832 6856848.981)   41.276557        286435
# 3814  POINT (647314.520 6856890.263)  148.441738        167205
# 263   POINT (649294.766 6857630.845)   80.140361        166823
# 1033  POINT (649054.277 6857944.809)   56.617679        286266
# 1678  POINT (648251.446 6857588.836)    6.624460        253512
# ...                              ...         ...           ...
# 5550  POINT (654362.408 6861787.940)    1.419036        288880
# 5506  POINT (653798.653 6863652.016)    1.520361        288874
# 5509  POINT (653479.693 6861540.229)    1.178435         55062
# 68    POINT (654985.600 6866640.432)    0.252026         81995
# 3073  POINT (654947.233 6866006.321)    4.594885         90096
#
#                id_local     id_osm code_com_d  \
# 2885   geovelo_37655991   37655991      92023
# 3814  geovelo_755707363  755707363      92020
# 263   geovelo_659513577  659513577      92049
# 1033   geovelo_25396506   25396506      92046
# 1678  geovelo_540065626  540065626      92046
# ...                 ...        ...        ...
# 5550    geovelo_8059156    8059156      75111
# 5506   geovelo_23695896   23695896      75110
# 5509  geovelo_390294218  390294218      75104
# 68    geovelo_632262545  632262545      75119
# 3073   geovelo_76607825   76607825      75119
#
#                                                ame_d          regime_d  \
# 2885                                           AUCUN  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 263                                            AUCUN  EN AGGLOMERATION
# 1033                                           AUCUN  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# ...                                              ...               ...
# 5550                                           AUCUN           ZONE 30
# 5506                                           AUCUN           ZONE 30
# 5509                                  BANDE CYCLABLE  EN AGGLOMERATION
# 68                                    BANDE CYCLABLE  EN AGGLOMERATION
# 3073                                  PISTE CYCLABLE           ZONE 30
#
#                sens_d  largeur_d   local_d    statut_d code_com_g  \
# 2885  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92023
# 3814  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92020
# 263   UNIDIRECTIONNEL        NaN      None  EN SERVICE      92049
# 1033  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE      92046
# ...               ...        ...       ...         ...        ...
# 5550  UNIDIRECTIONNEL        NaN      None  EN SERVICE      75111
# 5506  UNIDIRECTIONNEL        NaN      None  EN SERVICE      75110
# 5509  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      75104
# 68    UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE      75119
# 3073  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE      75119
#
#                                                ame_g          regime_g  \
# 2885                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 3814  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# 263                                   BANDE CYCLABLE  EN AGGLOMERATION
# 1033                            DOUBLE SENS CYCLABLE  EN AGGLOMERATION
# 1678  AMENAGEMENT MIXTES PIETON VELO HORS VOIE VERTE             AUTRE
# ...                                              ...               ...
# 5550                            DOUBLE SENS CYCLABLE           ZONE 30
# 5506                            DOUBLE SENS CYCLABLE           ZONE 30
# 5509                                           AUCUN              None
# 68                                             AUCUN              None
# 3073                                  PISTE CYCLABLE           ZONE 30
#
#                sens_g  largeur_g   local_g    statut_g access_ame  trafic_vit  \
# 2885  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 3814  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# 263   UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        50.0
# 1033  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 1678  UNIDIRECTIONNEL        NaN      None  EN SERVICE       None         5.0
# ...               ...        ...       ...         ...        ...         ...
# 5550  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 5506  UNIDIRECTIONNEL        NaN  CHAUSSEE  EN SERVICE       None        30.0
# 5509             None        NaN      None  EN SERVICE       None        50.0
# 68               None        NaN      None  EN SERVICE       None        50.0
# 3073  UNIDIRECTIONNEL        NaN  TROTTOIR  EN SERVICE       None        30.0
#
#      lumiere d_service                                         geometry_y  \
# 2885    None  inconnue  LINESTRING (646440.773 6856862.329, 646438.830...
# 3814    None  inconnue  LINESTRING (647271.267 6856742.089, 647274.993...
# 263     True  inconnue  LINESTRING (649246.431 6857566.922, 649242.525...
# 1033    True  inconnue  LINESTRING (649024.597 6857993.023, 649030.113...
# 1678    True  inconnue  LINESTRING (648264.439 6857585.820, 648257.143...
# ...      ...       ...                                                ...
# 5550    None  inconnue  LINESTRING (654412.662 6861652.496, 654409.502...
# 5506    None  inconnue  LINESTRING (653933.120 6863711.905, 653927.629...
# 5509    None  inconnue  LINESTRING (653440.046 6861521.177, 653444.257...
# 68      True  inconnue  LINESTRING (654998.850 6866656.653, 654985.656...
# 3073    None  inconnue  LINESTRING (654941.299 6865987.252, 654946.521...
#
#       count_accidents
# 2885                1
# 3814                1
# 263                 1
# 1033                1
# 1678                1
# ...               ...
# 5550                1
# 5506                1
# 5509                1
# 68                  1
# 3073                1
#
# [229 rows x 63 columns]

# %%
final_df_merged_grouped = final_df_merged.groupby(['nearest_road'])['count_accidents'].sum().reset_index()
final_df_merged_grouped
# Out:
#      nearest_road  count_accidents
# 6           12042                2
# 12          17079                2
# 15          19893                2
# 16          22840                4
# 17          23654                3
# 20          28287                2
# 22          29418                2
# 30          34528                2
# 31          34695                3
# 32          35195                2
# 33          35257                2
# 34          35801                2
# 35          35877                5
# 36          35993                2
# 40          37456                2
# 54          43366                2
# 55          43618                2
# 60          53860                2
# 78          73189                2
# 81          74301                4
# 82          74522                4
# 83          74533                3
# 87          74835                2
# 93          82099                2
# 106        119213                3
# 107        129378                2
# 108        132361                3
# 115        173969                2
# 122        181692                3
# 124        181891                2
# 128        192437                2
# 131        215667                2
# 134        220308                2
# 138        224664                2
# 140        253512                2
# 144        283832                2
# 168        288880                2
